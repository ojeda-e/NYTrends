# %%
import pandas as pd
import numpy as np
import json
from calendar import month_name

years = range(1990, 2019)

json_name = "NYT_archive_wordfreq_"+str(years[0])+"-"+str(years[-1])+".json"
#range()

with open(json_name) as f:
    headline = json.load(f)

print(headline.keys())
# Out:
# dict_keys(['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018'])

# %%
words_per_year = {}


for year in range(2016,2019): #headline.keys():
    word_list = []
    for month in range(1,13):
        word_list = word_list + [i for i in headline[str(year)][month_name[month]] ]

        
    words_per_year[year] = word_list

drop = ["It's", 'earnings', 'CHRONICLE', 'Corp.', 'reports', 'Record', 'Correction:', 'Inc.', 'Inc', 'Qtr.', 'Qtr', 'Nov', 'Dec', 'Jan', 'Briefly;', 'Review:', 'Than', '-', 'AND' ]

for key in range(2016,2019): #words_per_year.keys():
    for word in drop:
        if word in words_per_year[key]:
            words_per_year[key].remove(word)
        
#print(words_per_year)



# name = ['Trump'] #, 'Trump', 'Bush', 'Obama', "Clinton"]


# for i in name:
#     print(i)
#     for year in range(2000,2019):
#         for month in range(1,13):
#             if i in headline[year][month_name[month]]:
#                 print(year, month_name[month], headline[year][month_name[month]][i] )

# %%
pd.DataFrame(words_per_year.items())
# Out:
#       0                                                  1
# 0  2016  [Donald, Trump, Says, U.S., Dies, Jan., Ted, I...
# 1  2017  [Trump, Trump’s, Donald, Men’s, Dies, Briefing...
# 2  2018  [Trump, Trump’s, ‘The, U.S., Briefing, Week, D...

# %%
set2000= set(words_per_year[2017])

#for key in words_per_year.keys():
[t for t in set2000 if all(t in q for q in words_per_year.values() ) ]
# Out:
# ['War',
#  'Politics',
#  'Get',
#  'State',
#  'Supreme',
#  'It’s',
#  'Russian',
#  'Next',
#  'Leader',
#  'China',
#  'Still',
#  'President',
#  'House',
#  'Super',
#  'Than',
#  'Some',
#  'Russia',
#  'Things',
#  'Health',
#  'Another',
#  'Long',
#  'Million',
#  'de',
#  'Rules',
#  'Love',
#  'America',
#  'Tax',
#  'Dead',
#  'Week',
#  'Now',
#  'U.S.',
#  'Have',
#  'Chinese',
#  'Trump’s',
#  'White',
#  'Season',
#  'Fight',
#  'More',
#  'Time',
#  'Help',
#  'Corrections:',
#  'Trump,',
#  'Saudi',
#  'Real',
#  'Like',
#  'Take',
#  'Hurricane',
#  'Court',
#  'Climate',
#  'Open',
#  'Book',
#  'What’s',
#  'Donald',
#  'Our',
#  'Party',
#  'Playoffs',
#  '—',
#  'World',
#  'Times',
#  'Man',
#  'Summer',
#  'Why',
#  'Was',
#  'He',
#  'Best',
#  'Years',
#  'Life',
#  'Holiday',
#  'Down',
#  'John',
#  'Bill',
#  'Power',
#  'Attack',
#  'Make',
#  'Briefing',
#  'Report',
#  'G.O.P.',
#  'Could',
#  'Look',
#  'Plan',
#  'American',
#  'Should',
#  'Deal',
#  'Before',
#  'Police',
#  'James',
#  'Art',
#  'Way',
#  'Spring',
#  'NYC',
#  'Thanksgiving',
#  'Judge',
#  'Can',
#  'All',
#  'Market',
#  'Win',
#  'Episode',
#  'Case',
#  'Show',
#  'Top',
#  'Behind',
#  'So',
#  'Year',
#  'California',
#  'Change',
#  'Go',
#  'Syria',
#  'Day',
#  'TV',
#  'North',
#  'Election',
#  'Good',
#  'N.F.L.',
#  'Music',
#  'Fall',
#  'Race',
#  'Trump',
#  'Dies',
#  '‘The',
#  'South',
#  'My',
#  'Takes',
#  'Shooting',
#  'Quotation',
#  'Women',
#  'News',
#  'Fashion',
#  'School',
#  'Bowl',
#  'City',
#  'Gun',
#  'Today:',
#  'Review:',
#  'Michael',
#  'Just',
#  'Says',
#  'Christmas',
#  'Gets',
#  'Home',
#  'Don’t',
#  'End']

# %%
common_words = ['Trump', 'China', 'Russia', 'President', 'Donald', 'War', 'White', 'Saudi', 'Attack', 'Police', 'American', 'California', 'Syria', 'Shooting', 'Women', 'American', 'Power', 'Court']


word_dict = {word:{year:[] for year in range(2016,2019)} for word in common_words}
    
print(word_dict)
# Out:
# {'Trump': {2016: [], 2017: [], 2018: []}, 'China': {2016: [], 2017: [], 2018: []}, 'Russia': {2016: [], 2017: [], 2018: []}, 'President': {2016: [], 2017: [], 2018: []}, 'Donald': {2016: [], 2017: [], 2018: []}, 'War': {2016: [], 2017: [], 2018: []}, 'White': {2016: [], 2017: [], 2018: []}, 'Saudi': {2016: [], 2017: [], 2018: []}, 'Attack': {2016: [], 2017: [], 2018: []}, 'Police': {2016: [], 2017: [], 2018: []}, 'American': {2016: [], 2017: [], 2018: []}, 'California': {2016: [], 2017: [], 2018: []}, 'Syria': {2016: [], 2017: [], 2018: []}, 'Shooting': {2016: [], 2017: [], 2018: []}, 'Women': {2016: [], 2017: [], 2018: []}, 'Power': {2016: [], 2017: [], 2018: []}, 'Court': {2016: [], 2017: [], 2018: []}}

# %%
for word in common_words:
    for year in range(2016,2019):
        times_per_year=0
        for month in range(1,12):
            if word in headline[str(year)][month_name[month]]:
                times_per_year = times_per_year + headline[str(year)][month_name[month]][word]
                #print(word, headline[str(year)][month_name[month]][word])
        word_dict[word][year] = times_per_year

# %%
data = pd.DataFrame.from_dict({(i): word_dict[i]
                           for i in word_dict.keys() 
                           for j in word_dict[i].keys()
                           for k in word_dict[i].values()},
                       orient='index')

print(data)
# Out:
#             2016  2017  2018
# American     353   299   479
# Attack       126   158    98
# California   105   386   745
# China        467   325   645
# Court        533   382   513
# Donald      2205   442    86
# Police       653   480   526
# Power          0   156    96
# President    243   469   287
# Russia         0   289   278
# Saudi         32    58   188
# Shooting      66    35    48
# Syria         40    65    70
# Trump       2193  3416  3477
# War          178   368   574
# White         71   475   546
# Women        305   350   605

# %%
from math import pi
import pandas as pd

from bokeh.io import show
from bokeh.models import LinearColorMapper, BasicTicker, PrintfTickFormatter, ColorBar
from bokeh.plotting import figure




data.columns.name = 'Year'
data.set_index = 'Word'

print(data)

words = list(data.index)
years = list(data.columns)


df = pd.DataFrame(data.stack(), columns=['freq']).reset_index()
print(df)

colors = ["#75968f", "#a5bab7", "#c9d9d3", "#e2e2e2", "#dfccce", "#ddb7b1", "#cc7878", "#933b41", "#550b1d"]
mapper = LinearColorMapper(palette=colors, low=df.freq.min(), high=df.freq.max())

TOOLS = "hover,save,pan,box_zoom,reset,wheel_zoom"

p = figure(title="Most common words NYT Headers 2016-2019",
           x_range=list(words), y_range=(years[0], 2018),
           x_axis_location="above", plot_width=900, plot_height=400,
           tools=TOOLS, toolbar_location='below',
           tooltips=[('Word, Year', '@Word @Year'), ('frequency', '@freq')])


p.rect(x="Year", y="Word", width=1, height=1,
       source=df,
       fill_color={'field': 'freq', 'transform': mapper},
       line_color=None)

p.grid.grid_line_color = None
p.axis.axis_line_color = None
p.axis.major_tick_line_color = None
p.axis.major_label_text_font_size = "5pt"
p.axis.major_label_standoff = 0
p.xaxis.major_label_orientation = pi / 3

color_bar = ColorBar(color_mapper=mapper, major_label_text_font_size="5pt",
                     ticker=BasicTicker(desired_num_ticks=len(colors)),
                     formatter=PrintfTickFormatter(format="%d%%"),
                     label_standoff=6, border_line_color=None, location=(0, 0))

p.add_layout(color_bar, 'right')

show(p)
# Out:
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "y" value "Word" [renderer: GlyphRenderer(id='4004', ...)]
# Year        2016  2017  2018
# American     353   299   479
# Attack       126   158    98
# California   105   386   745
# China        467   325   645
# Court        533   382   513
# Donald      2205   442    86
# Police       653   480   526
# Power          0   156    96
# President    243   469   287
# Russia         0   289   278
# Saudi         32    58   188
# Shooting      66    35    48
# Syria         40    65    70
# Trump       2193  3416  3477
# War          178   368   574
# White         71   475   546
# Women        305   350   605
#        level_0  Year  freq
# 0     American  2016   353
# 1     American  2017   299
# 2     American  2018   479
# 3       Attack  2016   126
# 4       Attack  2017   158
# 5       Attack  2018    98
# 6   California  2016   105
# 7   California  2017   386
# 8   California  2018   745
# 9        China  2016   467
# 10       China  2017   325
# 11       China  2018   645
# 12       Court  2016   533
# 13       Court  2017   382
# 14       Court  2018   513
# 15      Donald  2016  2205
# 16      Donald  2017   442
# 17      Donald  2018    86
# 18      Police  2016   653
# 19      Police  2017   480
# 20      Police  2018   526
# 21       Power  2016     0
# 22       Power  2017   156
# 23       Power  2018    96
# 24   President  2016   243
# 25   President  2017   469
# 26   President  2018   287
# 27      Russia  2016     0
# 28      Russia  2017   289
# 29      Russia  2018   278
# 30       Saudi  2016    32
# 31       Saudi  2017    58
# 32       Saudi  2018   188
# 33    Shooting  2016    66
# 34    Shooting  2017    35
# 35    Shooting  2018    48
# 36       Syria  2016    40
# 37       Syria  2017    65
# 38       Syria  2018    70
# 39       Trump  2016  2193
# 40       Trump  2017  3416
# 41       Trump  2018  3477
# 42         War  2016   178
# 43         War  2017   368
# 44         War  2018   574
# 45       White  2016    71
# 46       White  2017   475
# 47       White  2018   546
# 48       Women  2016   305
# 49       Women  2017   350
# 50       Women  2018   605
